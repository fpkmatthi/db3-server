# %% [markdown]
# # Pandas Analytics - Example 2

# %%
import pandas as pd

# %% [raw]
# Read the file parking.csv into a dataframe
# It contains historical information about the available parking spots in 6 city parking garages in Gent

# %% [raw]
# Drop lines with duplicate "LastModified" field and keep the last line

# %% [raw]
# Read the file holidays.csv into a dataframe
# It contains the official school holidays
# Show the first 5 lines

# %%
# Out:
#          date
# 0  2017-12-23
# 1  2017-12-24
# 2  2017-12-25
# 3  2017-12-26
# 4  2017-12-27

# %% [raw]
# Add a column date to the parking dataframe that contains the date (no hours minutes or seconds).
# This column will look the same as the column date from the dataframe holidays

# %%
# Out:
#           LastModified                   Name  Available  Capacity  Open  \
# 0  2018-10-24 23:38:00       P01 Vrijdagmarkt        430       647  True
# 1  2018-10-24 23:38:00              P08 Ramen        147       266  True
# 2  2018-10-24 23:38:00               P02 Reep        383       470  True
# 3  2018-10-24 23:34:00  P10 Sint-Pietersplein        575       708  True
# 4  2018-10-24 23:43:00       P01 Vrijdagmarkt        433       647  True
#
#          date
# 0  2018-10-24
# 1  2018-10-24
# 2  2018-10-24
# 3  2018-10-24
# 4  2018-10-24

# %% [raw]
# Add a column holiday = 1 to the dataset holidays

# %%
# Out:
#          date  holiday
# 0  2017-12-23        1
# 1  2017-12-24        1
# 2  2017-12-25        1
# 3  2017-12-26        1
# 4  2017-12-27        1

# %% [raw]
# Merge both datasets

# %%
# Out:
#           LastModified                   Name  Available  Capacity  Open  \
# 0  2018-10-24 23:38:00       P01 Vrijdagmarkt        430       647  True
# 1  2018-10-24 23:38:00              P08 Ramen        147       266  True
# 2  2018-10-24 23:38:00               P02 Reep        383       470  True
# 3  2018-10-24 23:34:00  P10 Sint-Pietersplein        575       708  True
# 4  2018-10-24 23:43:00       P01 Vrijdagmarkt        433       647  True
#
#          date  holiday
# 0  2018-10-24      NaN
# 1  2018-10-24      NaN
# 2  2018-10-24      NaN
# 3  2018-10-24      NaN
# 4  2018-10-24      NaN

# %% [raw]
# Filter the rows where holiday = 1

# %%
# Out:
#              LastModified                   Name  Available  Capacity  Open  \
# 1029  2018-10-27 00:14:00      P07 Sint-Michiels        196       450  True
# 1030  2018-10-27 00:14:00  P10 Sint-Pietersplein        555       708  True
# 1031  2018-10-27 00:13:00       P01 Vrijdagmarkt        208       647  True
# 1032  2018-10-27 00:14:00       P04 Savaanstraat        521       540  True
# 1033  2018-10-27 00:13:00              P08 Ramen         52       266  True
# 1034  2018-10-27 00:12:00               P02 Reep        335       470  True
# 1035  2018-10-27 00:29:00      P07 Sint-Michiels        206       450  True
# 1036  2018-10-27 00:29:00  P10 Sint-Pietersplein        560       708  True
# 1037  2018-10-27 00:28:00       P01 Vrijdagmarkt        234       647  True
# 1038  2018-10-27 00:27:00       P04 Savaanstraat        523       540  True
# 1039  2018-10-27 00:29:00              P08 Ramen         59       266  True
# ...

# %% [raw]
# Replace the NaN in column holiday by 0

# %%
# Out:
#              LastModified                   Name  Available  Capacity  Open  \
# 0     2018-10-24 23:38:00       P01 Vrijdagmarkt        430       647  True
# 1     2018-10-24 23:38:00              P08 Ramen        147       266  True
# 2     2018-10-24 23:38:00               P02 Reep        383       470  True
# 3     2018-10-24 23:34:00  P10 Sint-Pietersplein        575       708  True
# 4     2018-10-24 23:43:00       P01 Vrijdagmarkt        433       647  True
# 5     2018-10-24 23:38:00      P07 Sint-Michiels        284       450  True
# 6     2018-10-24 23:44:00  P10 Sint-Pietersplein        574       708  True
# 7     2018-10-24 23:44:00       P01 Vrijdagmarkt        434       647  True
# 8     2018-10-24 23:39:00       P04 Savaanstraat        521       540  True
# 9     2018-10-24 23:42:00              P08 Ramen        148       266  True
# 10    2018-10-24 23:43:00               P02 Reep        386       470  True
# ...
